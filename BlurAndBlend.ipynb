# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('DATA/house2.jpg')
plt_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(plt_img)

# %%
# GAMMA BLUR
img1 = img.copy
gamma = 0.00000009
res = np.power(plt_img,gamma)
plt.imshow(res)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000004987138433].

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load Image
img = cv2.imread('DATA/house2.jpg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for Matplotlib

# Define a 5×5 Averaging Kernel
gamma = np.ones((5,5), np.float32) / 25  # Normalized kernel

# Apply the Filter
filtered = cv2.filter2D(img, -1, gamma)

# Display Original and Filtered Images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(filtered)
plt.title("Filtered Image")
plt.axis("off")

plt.show()

# %%
img2 = cv2.imread('DATA/bedroom glass balcony.jpg', cv2.IMREAD_COLOR)
res = cv2.blur(img2, ksize=(14,14))
plt.imshow(res)

# %%
res2 = cv2.putText(res, "My Bedroom", (10,450),cv2.FONT_HERSHEY_PLAIN , 7, (0,0,255), 8)
plt.imshow(res2)
